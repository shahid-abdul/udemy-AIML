# %%
! pip install seaborn

# %%
import seaborn as sns

# %%
# Basic Plotting with seaborn
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Scatter Plot

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title('Scatterplot')
# Out:
# Text(0.5, 1.0, 'Scatterplot')

# %% [markdown]
# ## Line Plot

# %%
sns.lineplot(x='size',y='total_bill',data=tips)
plt.title("This is the line plot of total bill based on size")
# Out:
# Text(0.5, 1.0, 'This is the line plot of total bill based on size')

# %% [markdown]
# ## Categorical Plots

# %%
sns.barplot(x='day',y='total_bill',data=tips)
plt.title("Bar plot of total bill")
# Out:
# Text(0.5, 1.0, 'Bar plot of total bill')

# %%
sns.boxplot(x='day',y='total_bill',data=tips)
plt.title("Box plot of total bill")
# Out:
# Text(0.5, 1.0, 'Box plot of total bill')

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Histograms

# %%
sns.histplot(tips['total_bill'],bins=10,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ## KDE Plot

# %%
sns.kdeplot(tips['total_bill'],shade=True,fill=True)
# Out:
# /var/folders/v3/lvzw67td78dg_zx8trtc3fc00000gn/T/ipykernel_22769/985873536.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips['total_bill'],shade=True,fill=True)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ## Pair plot

# %%
sns.pairplot(tips)

# %% [markdown]
# ## Heatmap

# %%
corr = tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
import pandas as pd

# %%
df = pd.read_csv('car_data.csv')
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Fuel_Type',y='Kms_Driven',data=df,estimator=sum)
plt.xlabel('Fuel_Type')
plt.ylabel('Kms_Driven')
# Out:
# Text(0, 0.5, 'Kms_Driven')

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Year',y='Kms_Driven',data=df,estimator=sum)
plt.xlabel('Year')
plt.ylabel('Kms_Driven')
# Out:
# Text(0, 0.5, 'Kms_Driven')
